# %% [markdown]
# <a href="https://colab.research.google.com/github/kszymon/seaborn-plotly/blob/main/plotly-tut/advanced%20/02_financial_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q chart_studio
# !pip install -q --upgrade plotly

# %%
def fetch_financial_data(company='AMZN'):
    """
    This function fetch stock market quotations.
    """
    import pandas_datareader.data as web
    return web.DataReader(name=company, data_source='stooq')

df_amzn = fetch_financial_data(company='AMZN')
df_aapl = fetch_financial_data(company='AAPL')
df_msft = fetch_financial_data(company='MSFT')
df_nflx = fetch_financial_data(company='NFLX')
df_nvda= fetch_financial_data(company='NVDA')

# %%
df_amzn.head(2)
# Out:
#               Open      High     Low   Close    Volume
# Date
# 2025-04-17  176.00  176.2100  172.00  172.61  44726453
# 2025-04-16  176.29  179.1046  171.41  174.33  51875316

# %%
import pandas as pd

df = pd.concat([df_amzn['Close'],df_aapl['Close'],df_msft['Close'],df_nflx['Close'], df_nvda['Close']], axis=1, join='inner')
df.columns = ['amazon', 'apple', 'microsoft', 'netflix', 'nvidia']
df = df.reset_index()
df.head()
# Out:
#         Date  amazon   apple  microsoft  netflix  nvidia
# 0 2025-04-17  172.61  196.98     367.78   973.03  101.49
# 1 2025-04-16  174.33  194.27     371.61   961.63  104.49
# 2 2025-04-15  179.59  202.14     385.73   976.28  112.20
# 3 2025-04-14  182.12  202.52     387.81   931.28  110.71
# 4 2025-04-11  184.87  198.15     388.45   918.29  110.93

# %%
df.describe()
# Out:
#                                 Date       amazon  ...      netflix       nvidia
# count                           1256  1256.000000  ...  1256.000000  1256.000000
# mean   2022-10-17 04:38:35.923567104   153.301340  ...   504.733360    45.274591
# min              2020-04-21 00:00:00    81.820000  ...   166.370000     6.713880
# 25%              2021-07-19 18:00:00   128.240000  ...   376.197500    14.882925
# 50%              2022-10-15 12:00:00   157.874000  ...   493.705000    23.510500
# 75%              2024-01-17 06:00:00   174.180250  ...   609.762500    56.547275
# max              2025-04-17 00:00:00   242.060000  ...  1058.600000   149.430000
# std                              NaN    33.177715  ...   188.874266    42.211680
#
# [8 rows x 6 columns]

# %%
import plotly.graph_objects as go

trace0 = go.Scatter(x=df.Date,
                   y=df.amazon,
                   name='Amazon')
trace1 = go.Scatter(x=df.Date,
                   y=df.apple,
                   name='Apple')
trace2 = go.Scatter(x=df.Date,
                   y=df.microsoft,
                   name='Microsoft')
trace3 = go.Scatter(x=df.Date,
                   y=df.netflix,
                   name='Netflix')
trace4 = go.Scatter(x=df.Date,
                    y = df.nvidia,
                    name = 'Nvidia')
data = [trace0, trace1, trace2, trace3, trace4]

layout = go.Layout(yaxis_type='log')

fig = go.Figure(data=data, layout=layout)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = go.Figure()

fig.add_trace(go.Scatter(
    x=df.Date,
    y=df.amazon,
    name='Amazon'
))

fig.add_trace(go.Scatter(
    x=df.Date,
    y=df.apple,
    name='Apple'
))

fig.update_layout(yaxis_type='log')

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
data = [go.Scatter(x=df.Date, y=df[col], name=col) for col in df.columns[1:]]
layout = go.Layout(yaxis_type='log')

fig = go.Figure(data=data, layout=layout)
fig.write_html('price.html')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
