# %% [markdown]
# <a href="https://colab.research.google.com/github/kszymon/seaborn-plotly/blob/main/plotly-tut%20/02_intro_part2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! pip install -q chart_studio
! pip install -q --upgrade plotly
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.4/64.4 kB 1.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.8/14.8 MB 16.4 MB/s eta 0:00:00

# %% [markdown]
# ### Szablony Plotly

# %%
import plotly.express as px

df=px.data.gapminder()
df.head(3)
# Out:
#        country continent  year  lifeExp       pop   gdpPercap iso_alpha  \
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314       AFG
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030       AFG
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710       AFG
#
#    iso_num
# 0        4
# 1        4
# 2        4

# %%
for template in ['plotly', 'plotly_white', 'plotly_dark', 'ggplot2', 'seaborn']:
    fig = px.scatter(df.query("year == 2007"), x='gdpPercap', y='lifeExp',
                       size='pop', color='continent', log_x=True, size_max=60,
                       height = 400, title=f'Template {template}', template=template)
    fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import plotly.io as pio

pio.templates.default = 'plotly_white'
df = px.data.iris()

fig  = px.scatter(df, x='sepal_width', y='petal_width')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
pio.templates.default = 'plotly_dark'
df = px.data.iris()

fig = px.scatter(df, x='sepal_width', y = 'petal_width')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
pio.templates.default = 'plotly'

# %% [markdown]
# ### Wykres powierzchniowy

# %%
import plotly.express as px

def fetch_financial_data(company='AMZN'):
    """
    This function fetch stock market quotations.
    """
    import pandas_datareader.data as web
    return web.DataReader(name = company, data_source='stooq')

df = fetch_financial_data()
df = df.reset_index()
df.head()
# Out:
#         Date    Open      High       Low   Close    Volume
# 0 2025-04-17  176.00  176.2100  172.0000  172.61  44726453
# 1 2025-04-16  176.29  179.1046  171.4100  174.33  51875316
# 2 2025-04-15  181.41  182.3500  177.9331  179.59  43641952
# 3 2025-04-14  186.84  187.4400  179.2300  182.12  48002540
# 4 2025-04-11  179.93  185.8600  178.0000  184.87  50594339

# %%
df.describe()
# Out:
#                                 Date         Open         High          Low  \
# count                           1257  1257.000000  1257.000000  1257.000000
# mean   2022-10-16 11:15:53.699283968   153.322585   155.199070   151.285808
# min              2020-04-20 00:00:00    82.800000    83.480000    81.430000
# 25%              2021-07-19 00:00:00   128.250000   130.230000   126.340000
# 50%              2022-10-14 00:00:00   157.888000   159.694000   156.000000
# 75%              2024-01-17 00:00:00   174.479000   176.210000   172.600000
# max              2025-04-17 00:00:00   239.015000   242.520000   238.030000
# std                              NaN    33.206462    33.324582    32.986361
#
#              Close        Volume
# count  1257.000000  1.257000e+03
# mean    153.274593  6.462088e+07
# min      81.820000  1.500750e+07
# 25%     128.210000  4.405980e+07
# 50%     157.848000  5.787232e+07
# 75%     174.171000  7.654242e+07
# max     242.060000  2.726617e+08
# ...

# %%
df = df[df['Date']>= '2025-01-01']
df.describe()
# Out:
#                                 Date        Open        High         Low  \
# count                             73   73.000000   73.000000   73.000000
# mean   2025-02-25 02:18:04.931506944  210.547356  213.540800  207.126592
# min              2025-01-02 00:00:00  162.000000  176.210000  161.380000
# 25%              2025-01-30 00:00:00  193.900000  198.650000  191.960000
# 50%              2025-02-26 00:00:00  214.940000  217.715000  208.370000
# 75%              2025-03-24 00:00:00  228.820000  229.890000  225.860000
# max              2025-04-17 00:00:00  239.015000  242.520000  238.030000
# std                              NaN   20.445890   19.150024   21.132033
#
#             Close        Volume
# count   73.000000  7.300000e+01
# mean   210.540959  4.572395e+07
# min    170.660000  2.371373e+07
# 25%    195.540000  3.184983e+07
# 50%    212.710000  4.126732e+07
# 75%    228.680000  5.187532e+07
# max    242.060000  1.231594e+08
# std     20.197632  2.063776e+07

# %%
px.area(df, x='Date', y='Close', log_y=True, title='Wykres ceny spółki Amazon')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### Wykres słupkowy

# %%
from seaborn import load_dataset
import pandas as pd

df = load_dataset('flights')
df.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
df.describe()
# Out:
#               year  passengers
# count   144.000000  144.000000
# mean   1954.500000  280.298611
# std       3.464102  119.966317
# min    1949.000000  104.000000
# 25%    1951.750000  180.000000
# 50%    1954.500000  265.500000
# 75%    1957.250000  360.500000
# max    1960.000000  622.000000

# %%
px.bar(df, x='year', y ='passengers', title='Liczba pasażerów w podziale na lata.')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
px.bar(df, x='year', y ='passengers', color='month', title='Liczba pasażerów w podziale na lata.')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
px.bar(df, x='month', y='passengers',color='year', title='Liczba pasażerów w podziale na miesiące')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
px.bar(df, y='month', x='passengers', color='year', title='Liczba pasażerów w podziale na miesiące',
       orientation='h')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
px.bar(df.query('year in [1958, 1959, 1960]'), x='month', y='passengers', color='year')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### Wykres Gantta

# %%
import plotly.figure_factory as ff

df = [dict(Task='Projekt A', Start="2019-01-01", Finish='2019-06-01'),
      dict(Task='Project B', Start="2019-03-01", Finish='2019-07-01'),
      dict(Task='Project C', Start="2019-02-01", Finish='2019-04-01'),
      dict(Task='Project D', Start="2019-04-01", Finish='2019-10-01')]

ff.create_gantt(df)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df = [dict(Task='Projekt A', Start="2019-01-01", Finish='2019-06-01', Complete=10),
     dict(Task='Projekt B', Start="2019-03-01", Finish='2019-07-01', Complete=50),
     dict(Task='Projekt C', Start="2019-02-01", Finish='2019-04-01', Complete=100),
     dict(Task='Projekt D', Start="2019-04-01", Finish='2019-10-01', Complete=70)]

ff.create_gantt(df, colors=['#eb4034', '#34eb89'], index_col='Complete', show_colorbar=True, tasks=4)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## Wykres Kołowy i Pierścieniowy

# %%
df = load_dataset('diamonds')
df.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
df.describe()
# Out:
#               carat         depth         table         price             x  \
# count  53940.000000  53940.000000  53940.000000  53940.000000  53940.000000
# mean       0.797940     61.749405     57.457184   3932.799722      5.731157
# std        0.474011      1.432621      2.234491   3989.439738      1.121761
# min        0.200000     43.000000     43.000000    326.000000      0.000000
# 25%        0.400000     61.000000     56.000000    950.000000      4.710000
# 50%        0.700000     61.800000     57.000000   2401.000000      5.700000
# 75%        1.040000     62.500000     59.000000   5324.250000      6.540000
# max        5.010000     79.000000     95.000000  18823.000000     10.740000
#
#                   y             z
# count  53940.000000  53940.000000
# mean       5.734526      3.538734
# std        1.142135      0.705699
# min        0.000000      0.000000
# 25%        4.720000      2.910000
# 50%        5.710000      3.530000
# 75%        6.540000      4.040000
# ...

# %%
df = df.cut.value_counts()
df = df.reset_index()
df
# Out:
#          cut  count
# 0      Ideal  21551
# 1    Premium  13791
# 2  Very Good  12082
# 3       Good   4906
# 4       Fair   1610

# %%
import plotly.graph_objects as go

fig = go.Figure(data=[go.Pie(labels=df.index, values=df.cut)])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = go.Figure(data=[go.Pie(labels=df.index, values=df.cut, hole=0.5)])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### Tabele

# %%
fig = go.Figure(data=[go.Table(header=dict(values=['USER ID', 'Amount'],
                                          fill_color='lightblue',
                                          line_color='gray'),
                              cells=dict(values=[['010', '019', '013', '031'], [100, 150, 80, 120]],
                                        fill_color='lightgreen'))],
               layout=go.Layout(width=500, height=300))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df = load_dataset('flights')
df.head(3)
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132

# %%
df = df[:20]
len(df)
# Out:
# 20

# %%
data = [go.Table(header=dict(values=df.columns),
                 cells=dict(values=[df.year, df.month, df.passengers]))]
fig = go.Figure(data=data)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### Diagram Sankey'a

# %%
# total = 100
# Non-Churn_2018 -> Non-Churn_2019 (65)
# Non-Churn_2018 -> Churn_2019 (12)
# Churn_2018 -> Churn_2019 (18)
# Churn_2018 -> Non-Churn_2019 (5)

data = [go.Sankey(node=dict(label=['Nonchurn_2018', 'Churn_2018','Nonchurn_2019', 'Churn_2019']),
                link=dict(source=[0, 0, 1, 1], # indeks odpowiadający etykiecie (labels)
                          target=[2, 3, 2, 3],
                          value=[65, 12, 18, 5]))]

fig = go.Figure(data=data)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
data = [go.Sankey(node=dict(label=['Nonchurn_2018', 'Churn_2018', 'Nonchurn_2019', 'Churn_2019', 'Nonchurn_2020', 'Churn_2020']),
                 link=dict(source=[0, 0, 1, 1, 2, 3], # indeks odpowiadający etykiecie (labels)
                          target=[2, 3, 2, 3, 4, 5],
                          value=[65, 10, 5, 20, 70, 30]))]

fig = go.Figure(data=data)
fig.show()
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
